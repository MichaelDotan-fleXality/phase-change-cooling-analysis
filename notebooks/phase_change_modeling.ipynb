# %% [markdown]
# # Phase-Change Cooling System Modeling
#
# This notebook explores the modeling of phase-change cooling systems, including:
# - Latent heat effects
# - Phase transition modeling
# - Efficiency calculations

# %%
import sys
import os
sys.path.append(os.path.join(os.path.dirname(os.getcwd()), '..'))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from analysis.phase_change_models import (
    estimate_electric_power_phase_change_cooling,
    calculate_phase_change_efficiency
)
